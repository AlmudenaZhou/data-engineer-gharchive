# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %%
# parser = argparse.ArgumentParser()

# parser.add_argument('--input_green', required=True)
# parser.add_argument('--output', required=True)

# args = parser.parse_args()

# input_green = args.input_green
# input_yellow = args.input_yellow
# output = args.output

input_path = './data/2015-01-01-*.parquet'


spark = SparkSession.builder \
    .appName('test') \
    .getOrCreate()

# spark.conf.set('temporaryGcsBucket', 'my-project-12345/temp-folder')

df = spark.read.parquet(input_path)

# %%
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- payload: struct (nullable = true)
#  |    |-- action: string (nullable = true)
#  |    |-- before: string (nullable = true)
#  |    |-- comment: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- self: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- commit_id: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- diff_hunk: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- issue_url: string (nullable = true)
#  |    |    |-- line: long (nullable = true)
#  |    |    |-- original_commit_id: string (nullable = true)
#  |    |    |-- original_position: long (nullable = true)
#  |    |    |-- path: string (nullable = true)
#  |    |    |-- position: long (nullable = true)
#  |    |    |-- pull_request_url: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- commits: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- author: struct (nullable = true)
#  |    |    |    |    |-- email: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- distinct: boolean (nullable = true)
#  |    |    |    |-- message: string (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- distinct_size: long (nullable = true)
#  |    |-- forkee: struct (nullable = true)
#  |    |    |-- archive_url: string (nullable = true)
#  |    |    |-- assignees_url: string (nullable = true)
#  |    |    |-- blobs_url: string (nullable = true)
#  |    |    |-- branches_url: string (nullable = true)
#  |    |    |-- clone_url: string (nullable = true)
#  |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- commits_url: string (nullable = true)
#  |    |    |-- compare_url: string (nullable = true)
#  |    |    |-- contents_url: string (nullable = true)
#  |    |    |-- contributors_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_branch: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- downloads_url: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- fork: boolean (nullable = true)
#  |    |    |-- forks: long (nullable = true)
#  |    |    |-- forks_count: long (nullable = true)
#  |    |    |-- forks_url: string (nullable = true)
#  |    |    |-- full_name: string (nullable = true)
#  |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |-- git_url: string (nullable = true)
#  |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |-- homepage: string (nullable = true)
#  |    |    |-- hooks_url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |-- issues_url: string (nullable = true)
#  |    |    |-- keys_url: string (nullable = true)
#  |    |    |-- labels_url: string (nullable = true)
#  |    |    |-- language: string (nullable = true)
#  |    |    |-- languages_url: string (nullable = true)
#  |    |    |-- merges_url: string (nullable = true)
#  |    |    |-- milestones_url: string (nullable = true)
#  |    |    |-- mirror_url: integer (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- notifications_url: string (nullable = true)
#  |    |    |-- open_issues: long (nullable = true)
#  |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |-- owner: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- private: boolean (nullable = true)
#  |    |    |-- public: boolean (nullable = true)
#  |    |    |-- pulls_url: string (nullable = true)
#  |    |    |-- pushed_at: string (nullable = true)
#  |    |    |-- releases_url: string (nullable = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- ssh_url: string (nullable = true)
#  |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |-- statuses_url: string (nullable = true)
#  |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |-- subscription_url: string (nullable = true)
#  |    |    |-- svn_url: string (nullable = true)
#  |    |    |-- tags_url: string (nullable = true)
#  |    |    |-- teams_url: string (nullable = true)
#  |    |    |-- trees_url: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- watchers: long (nullable = true)
#  |    |    |-- watchers_count: long (nullable = true)
#  |    |-- head: string (nullable = true)
#  |    |-- issue: struct (nullable = true)
#  |    |    |-- assignee: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- closed_at: string (nullable = true)
#  |    |    |-- comments: long (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- labels: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- labels_url: string (nullable = true)
#  |    |    |-- locked: boolean (nullable = true)
#  |    |    |-- milestone: struct (nullable = true)
#  |    |    |    |-- closed_at: string (nullable = true)
#  |    |    |    |-- closed_issues: long (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- creator: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- due_on: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |-- number: long (nullable = true)
#  |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- number: long (nullable = true)
#  |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |-- diff_url: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- patch_url: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- master_branch: string (nullable = true)
#  |    |-- member: struct (nullable = true)
#  |    |    |-- avatar_url: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- followers_url: string (nullable = true)
#  |    |    |-- following_url: string (nullable = true)
#  |    |    |-- gists_url: string (nullable = true)
#  |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- login: string (nullable = true)
#  |    |    |-- organizations_url: string (nullable = true)
#  |    |    |-- received_events_url: string (nullable = true)
#  |    |    |-- repos_url: string (nullable = true)
#  |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |-- starred_url: string (nullable = true)
#  |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- number: long (nullable = true)
#  |    |-- pages: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- action: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- page_name: string (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- summary: integer (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |-- pull_request: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- comments: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- commits: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- issue: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- review_comment: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- review_comments: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- self: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- statuses: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- additions: long (nullable = true)
#  |    |    |-- assignee: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- base: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- repo: struct (nullable = true)
#  |    |    |    |    |-- archive_url: string (nullable = true)
#  |    |    |    |    |-- assignees_url: string (nullable = true)
#  |    |    |    |    |-- blobs_url: string (nullable = true)
#  |    |    |    |    |-- branches_url: string (nullable = true)
#  |    |    |    |    |-- clone_url: string (nullable = true)
#  |    |    |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |    |    |-- comments_url: string (nullable = true)
#  |    |    |    |    |-- commits_url: string (nullable = true)
#  |    |    |    |    |-- compare_url: string (nullable = true)
#  |    |    |    |    |-- contents_url: string (nullable = true)
#  |    |    |    |    |-- contributors_url: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- default_branch: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- downloads_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- fork: boolean (nullable = true)
#  |    |    |    |    |-- forks: long (nullable = true)
#  |    |    |    |    |-- forks_count: long (nullable = true)
#  |    |    |    |    |-- forks_url: string (nullable = true)
#  |    |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |    |    |-- git_url: string (nullable = true)
#  |    |    |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |    |    |-- homepage: string (nullable = true)
#  |    |    |    |    |-- hooks_url: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |    |    |-- issues_url: string (nullable = true)
#  |    |    |    |    |-- keys_url: string (nullable = true)
#  |    |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- languages_url: string (nullable = true)
#  |    |    |    |    |-- merges_url: string (nullable = true)
#  |    |    |    |    |-- milestones_url: string (nullable = true)
#  |    |    |    |    |-- mirror_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- notifications_url: string (nullable = true)
#  |    |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- private: boolean (nullable = true)
#  |    |    |    |    |-- pulls_url: string (nullable = true)
#  |    |    |    |    |-- pushed_at: string (nullable = true)
#  |    |    |    |    |-- releases_url: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- ssh_url: string (nullable = true)
#  |    |    |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |    |    |-- statuses_url: string (nullable = true)
#  |    |    |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |    |    |-- subscription_url: string (nullable = true)
#  |    |    |    |    |-- svn_url: string (nullable = true)
#  |    |    |    |    |-- tags_url: string (nullable = true)
#  |    |    |    |    |-- teams_url: string (nullable = true)
#  |    |    |    |    |-- trees_url: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- watchers: long (nullable = true)
#  |    |    |    |    |-- watchers_count: long (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- user: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- changed_files: long (nullable = true)
#  |    |    |-- closed_at: string (nullable = true)
#  |    |    |-- comments: long (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- commits: long (nullable = true)
#  |    |    |-- commits_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- deletions: long (nullable = true)
#  |    |    |-- diff_url: string (nullable = true)
#  |    |    |-- head: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- repo: struct (nullable = true)
#  |    |    |    |    |-- archive_url: string (nullable = true)
#  |    |    |    |    |-- assignees_url: string (nullable = true)
#  |    |    |    |    |-- blobs_url: string (nullable = true)
#  |    |    |    |    |-- branches_url: string (nullable = true)
#  |    |    |    |    |-- clone_url: string (nullable = true)
#  |    |    |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |    |    |-- comments_url: string (nullable = true)
#  |    |    |    |    |-- commits_url: string (nullable = true)
#  |    |    |    |    |-- compare_url: string (nullable = true)
#  |    |    |    |    |-- contents_url: string (nullable = true)
#  |    |    |    |    |-- contributors_url: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- default_branch: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- downloads_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- fork: boolean (nullable = true)
#  |    |    |    |    |-- forks: long (nullable = true)
#  |    |    |    |    |-- forks_count: long (nullable = true)
#  |    |    |    |    |-- forks_url: string (nullable = true)
#  |    |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |    |    |-- git_url: string (nullable = true)
#  |    |    |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |    |    |-- homepage: string (nullable = true)
#  |    |    |    |    |-- hooks_url: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |    |    |-- issues_url: string (nullable = true)
#  |    |    |    |    |-- keys_url: string (nullable = true)
#  |    |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- languages_url: string (nullable = true)
#  |    |    |    |    |-- merges_url: string (nullable = true)
#  |    |    |    |    |-- milestones_url: string (nullable = true)
#  |    |    |    |    |-- mirror_url: integer (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- notifications_url: string (nullable = true)
#  |    |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- private: boolean (nullable = true)
#  |    |    |    |    |-- pulls_url: string (nullable = true)
#  |    |    |    |    |-- pushed_at: string (nullable = true)
#  |    |    |    |    |-- releases_url: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- ssh_url: string (nullable = true)
#  |    |    |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |    |    |-- statuses_url: string (nullable = true)
#  |    |    |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |    |    |-- subscription_url: string (nullable = true)
#  |    |    |    |    |-- svn_url: string (nullable = true)
#  |    |    |    |    |-- tags_url: string (nullable = true)
#  |    |    |    |    |-- teams_url: string (nullable = true)
#  |    |    |    |    |-- trees_url: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- watchers: long (nullable = true)
#  |    |    |    |    |-- watchers_count: long (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- user: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- issue_url: string (nullable = true)
#  |    |    |-- locked: boolean (nullable = true)
#  |    |    |-- merge_commit_sha: string (nullable = true)
#  |    |    |-- mergeable: boolean (nullable = true)
#  |    |    |-- mergeable_state: string (nullable = true)
#  |    |    |-- merged: boolean (nullable = true)
#  |    |    |-- merged_at: string (nullable = true)
#  |    |    |-- merged_by: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- milestone: struct (nullable = true)
#  |    |    |    |-- closed_at: integer (nullable = true)
#  |    |    |    |-- closed_issues: long (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- creator: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- due_on: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |-- number: long (nullable = true)
#  |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- number: long (nullable = true)
#  |    |    |-- patch_url: string (nullable = true)
#  |    |    |-- review_comment_url: string (nullable = true)
#  |    |    |-- review_comments: long (nullable = true)
#  |    |    |-- review_comments_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- statuses_url: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- push_id: long (nullable = true)
#  |    |-- pusher_type: string (nullable = true)
#  |    |-- ref: string (nullable = true)
#  |    |-- ref_type: string (nullable = true)
#  |    |-- release: struct (nullable = true)
#  |    |    |-- assets: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- browser_download_url: string (nullable = true)
#  |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- download_count: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- label: integer (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- uploader: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- assets_url: string (nullable = true)
#  |    |    |-- author: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- draft: boolean (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- prerelease: boolean (nullable = true)
#  |    |    |-- published_at: string (nullable = true)
#  |    |    |-- tag_name: string (nullable = true)
#  |    |    |-- tarball_url: string (nullable = true)
#  |    |    |-- target_commitish: string (nullable = true)
#  |    |    |-- upload_url: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- zipball_url: string (nullable = true)
#  |    |-- size: long (nullable = true)
#  |-- public: boolean (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- actor_id: long (nullable = true)
#  |-- actor_login: string (nullable = true)
#  |-- actor_gravatar_id: string (nullable = true)
#  |-- actor_url: string (nullable = true)
#  |-- actor_avatar_url: string (nullable = true)
#  |-- repo_id: long (nullable = true)
#  |-- repo_name: string (nullable = true)
#  |-- repo_url: string (nullable = true)
#  |-- org_id: long (nullable = true)
#  |-- org_login: string (nullable = true)
#  |-- org_gravatar_id: string (nullable = true)
#  |-- org_url: string (nullable = true)
#  |-- org_avatar_url: string (nullable = true)
#  |-- other: double (nullable = true)

# %%
df.head(5)
# Out:
# [Row(id='2489820999', type='PushEvent', payload=Row(action=None, before='f82e216b716e3c742b70ad93b7b4e5a0b48ec06c', comment=None, commits=[Row(author=Row(email='d9a6d2bb567014711b5561d09010c93ea738d23a@gmail.com', name='franklingu'), distinct=False, message='page needs quite some time to respond though', sha='494d6af175760f74db0b6470412b4d18b7be325c', url='https://api.github.com/repos/nusmodifications/nusmods/commits/494d6af175760f74db0b6470412b4d18b7be325c'), Row(author=Row(email='d9a6d2bb567014711b5561d09010c93ea738d23a@gmail.com', name='franklingu'), distinct=False, message='change from selectNone to manually deselect\n\nperformance issue seems to be slightly better. however,\nwith more options selected, the performance will downgrade.\na solution would be just set all models selected to be false\nand manually call onFilter once only', sha='a9867a173a7eda0bf2c10e93cef66fc8fb7383ce', url='https://api.github.com/repos/nusmodifications/nusmods/commits/a9867a173a7eda0bf2c10e93cef66fc8fb7383ce'), Row(author=Row(email='d2e7a9fdd15b41188916d6d38244e43571c36b1a@gmail.com', name='Tay Yang Shun'), distinct=False, message='Updated reset filters functionality for latest code', sha='53f7821d32ce2ca7c47f52bfdc5ff035711f44b2', url='https://api.github.com/repos/nusmodifications/nusmods/commits/53f7821d32ce2ca7c47f52bfdc5ff035711f44b2')], description=None, distinct_size=0, forkee=None, head='53f7821d32ce2ca7c47f52bfdc5ff035711f44b2', issue=None, master_branch=None, member=None, number=None, pages=None, pull_request=None, push_id=536939676, pusher_type=None, ref='refs/heads/master', ref_type=None, release=None, size=3), public=True, created_at=datetime.datetime(2015, 1, 1, 22, 0), actor_id=1315101, actor_login='yangshun', actor_gravatar_id='', actor_url='https://api.github.com/users/yangshun', actor_avatar_url='https://avatars.githubusercontent.com/u/1315101?', repo_id=5481861, repo_name='nusmodifications/nusmods', repo_url='https://api.github.com/repos/nusmodifications/nusmods', org_id=7428865, org_login='nusmodifications', org_gravatar_id='', org_url='https://api.github.com/orgs/nusmodifications', org_avatar_url='https://avatars.githubusercontent.com/u/7428865?', other=None),
#  Row(id='2489821022', type='CreateEvent', payload=Row(action=None, before=None, comment=None, commits=None, description='', distinct_size=None, forkee=None, head=None, issue=None, master_branch='master', member=None, number=None, pages=None, pull_request=None, push_id=None, pusher_type='user', ref='master', ref_type='branch', release=None, size=None), public=True, created_at=datetime.datetime(2015, 1, 1, 22, 0), actor_id=1465957, actor_login='siegessa', actor_gravatar_id='', actor_url='https://api.github.com/users/siegessa', actor_avatar_url='https://avatars.githubusercontent.com/u/1465957?', repo_id=28695494, repo_name='siegessa/koica', repo_url='https://api.github.com/repos/siegessa/koica', org_id=None, org_login=None, org_gravatar_id=None, org_url=None, org_avatar_url=None, other=None),
#  Row(id='2489821023', type='CreateEvent', payload=Row(action=None, before=None, comment=None, commits=None, description='test', distinct_size=None, forkee=None, head=None, issue=None, master_branch='master', member=None, number=None, pages=None, pull_request=None, push_id=None, pusher_type='user', ref=None, ref_type='repository', release=None, size=None), public=True, created_at=datetime.datetime(2015, 1, 1, 22, 0, 1), actor_id=135443, actor_login='gfredericks', actor_gravatar_id='', actor_url='https://api.github.com/users/gfredericks', actor_avatar_url='https://avatars.githubusercontent.com/u/135443?', repo_id=28695518, repo_name='gfredericks/jdk', repo_url='https://api.github.com/repos/gfredericks/jdk', org_id=None, org_login=None, org_gravatar_id=None, org_url=None, org_avatar_url=None, other=None),
#  Row(id='2489821024', type='CreateEvent', payload=Row(action=None, before=None, comment=None, commits=None, description='Assets, marketing, native, and data collection for Drone-MotherFucker.com enterprise.', distinct_size=None, forkee=None, head=None, issue=None, master_branch='master', member=None, number=None, pages=None, pull_request=None, push_id=None, pusher_type='user', ref=None, ref_type='repository', release=None, size=None), public=True, created_at=datetime.datetime(2015, 1, 1, 22, 0, 1), actor_id=8621141, actor_login='robot-pigeon', actor_gravatar_id='', actor_url='https://api.github.com/users/robot-pigeon', actor_avatar_url='https://avatars.githubusercontent.com/u/8621141?', repo_id=28695517, repo_name='drone-motherfucker/assets-marketing', repo_url='https://api.github.com/repos/drone-motherfucker/assets-marketing', org_id=8621154, org_login='drone-motherfucker', org_gravatar_id='', org_url='https://api.github.com/orgs/drone-motherfucker', org_avatar_url='https://avatars.githubusercontent.com/u/8621154?', other=None),
#  Row(id='2489821026', type='IssueCommentEvent', payload=Row(action='created', before=None, comment=Row(_links=None, body="Probably best we don't auto fix for now I suppose - good idea.", commit_id=None, created_at='2015-01-01T21:00:00Z', diff_hunk=None, html_url='https://github.com/tdharris/dsapp/issues/38#issuecomment-68498086', id=68498086, issue_url='https://api.github.com/repos/tdharris/dsapp/issues/38', line=None, original_commit_id=None, original_position=None, path=None, position=None, pull_request_url=None, updated_at='2015-01-01T21:00:00Z', url='https://api.github.com/repos/tdharris/dsapp/issues/comments/68498086', user=Row(avatar_url='https://avatars.githubusercontent.com/u/5355939?v=3', events_url='https://api.github.com/users/tdharris/events{/privacy}', followers_url='https://api.github.com/users/tdharris/followers', following_url='https://api.github.com/users/tdharris/following{/other_user}', gists_url='https://api.github.com/users/tdharris/gists{/gist_id}', gravatar_id='', html_url='https://github.com/tdharris', id=5355939, login='tdharris', organizations_url='https://api.github.com/users/tdharris/orgs', received_events_url='https://api.github.com/users/tdharris/received_events', repos_url='https://api.github.com/users/tdharris/repos', site_admin=False, starred_url='https://api.github.com/users/tdharris/starred{/owner}{/repo}', subscriptions_url='https://api.github.com/users/tdharris/subscriptions', type='User', url='https://api.github.com/users/tdharris')), commits=None, description=None, distinct_size=None, forkee=None, head=None, issue=Row(assignee=None, body="Check to see if any users are only in one connector. If so, deliver results of what users and what db they were found in and which they weren't. Then prompt for them to be deleted. Go through systematically and delete from tables properly and clean up attachments.", closed_at='2015-01-01T21:00:01Z', comments=2, comments_url='https://api.github.com/repos/tdharris/dsapp/issues/38/comments', created_at='2014-06-16T21:20:25Z', events_url='https://api.github.com/repos/tdharris/dsapp/issues/38/events', html_url='https://github.com/tdharris/dsapp/issues/38', id=35837387, labels=[Row(color='84b6eb', name='enhancement', url='https://api.github.com/repos/tdharris/dsapp/labels/enhancement')], labels_url='https://api.github.com/repos/tdharris/dsapp/issues/38/labels{/name}', locked=False, milestone=None, number=38, pull_request=None, state='closed', title='Fix Users Connectors', updated_at='2015-01-01T21:00:01Z', url='https://api.github.com/repos/tdharris/dsapp/issues/38', user=Row(avatar_url='https://avatars.githubusercontent.com/u/5355939?v=3', events_url='https://api.github.com/users/tdharris/events{/privacy}', followers_url='https://api.github.com/users/tdharris/followers', following_url='https://api.github.com/users/tdharris/following{/other_user}', gists_url='https://api.github.com/users/tdharris/gists{/gist_id}', gravatar_id='', html_url='https://github.com/tdharris', id=5355939, login='tdharris', organizations_url='https://api.github.com/users/tdharris/orgs', received_events_url='https://api.github.com/users/tdharris/received_events', repos_url='https://api.github.com/users/tdharris/repos', site_admin=False, starred_url='https://api.github.com/users/tdharris/starred{/owner}{/repo}', subscriptions_url='https://api.github.com/users/tdharris/subscriptions', type='User', url='https://api.github.com/users/tdharris')), master_branch=None, member=None, number=None, pages=None, pull_request=None, push_id=None, pusher_type=None, ref=None, ref_type=None, release=None, size=None), public=True, created_at=datetime.datetime(2015, 1, 1, 22, 0, 1), actor_id=5355939, actor_login='tdharris', actor_gravatar_id='', actor_url='https://api.github.com/users/tdharris', actor_avatar_url='https://avatars.githubusercontent.com/u/5355939?', repo_id=14152038, repo_name='tdharris/dsapp', repo_url='https://api.github.com/repos/tdharris/dsapp', org_id=None, org_login=None, org_gravatar_id= ...

# %%
output = 'gharchive_capstone_project'


df.write.format('bigquery') \
    .option('table', output) \
    .save()
