# %%
import urllib.request
import zlib
import pandas as pd
import numpy as np
import json
import datetime

# %% [markdown]
# # Cleaning the dataset structure

# %% [markdown]
# I will be using for this test the '2015-01-01-15.json.gz' file

# %% [markdown]
# ### Download and transform to a json form

# %%
year = 2015
month = 1
day = 1
hour = 15

# %% [markdown]
# The header with the user-agent is important since without it, the page denegate the access.

# %%
def download_gharchive_data(year, month, day, hour):
    url = f'http://data.gharchive.org/{year}-{month:02}-{day:02}-{hour}.json.gz'
    req = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    response = urllib.request.urlopen(req)
    compressed_data = response.read()
    
    return compressed_data

# %% [markdown]
# - Decompress the data
# - Since there was no list, it could not be loaded via json.loads directly =>
# => split by line and then each line read to convert it to a dictionary =>
# list of dictionaries to a pandas dataframe

# %%
def compressed_data_to_list_of_dicts(compressed_data):
    decompressed_data = zlib.decompress(compressed_data, 16 + zlib.MAX_WBITS)

    decoded_lines = decompressed_data.decode('utf-8').split('\n')
    decoded_lines = filter(lambda x: x != '', decoded_lines) 

    json_decoded_lines = [json.loads(line) for line in decoded_lines]
    return json_decoded_lines

# %%
compressed_data = download_gharchive_data(year, month, day, hour)
json_decoded_lines = compressed_data_to_list_of_dicts(compressed_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-183-14dcf17de8e9> in <module>
# ----> 1 compressed_data = download_gharchive_data(year, month, day, hour)
#
# NameError: name 'download_gharchive_data' is not defined

# %% [markdown]
# ### Implement the schema

# %% [markdown]
# I based my schema on https://github.com/igrigorik/gharchive.org/blob/master/bigquery/schema.js

# %% [markdown]
# - Pandas dataframe
# - created_at column to datetime
# - columns with a fixed maximum of json keys (`actor`, `repo`, `org`), are expanded
# to columns in the table following the formula for each column name: colname_key
# - columns with variable json format (`payload`, `other`) has been left as dictionaries
# - After performing this, the dataframe will be check against the schema:
#     - Check the columns:
#         - add missing columns
#         - drop those who should not exist (sometimes happens when expanding the jsons)
#     - Apply the dtypes in the schema into the dataframe
#
#     Note: `org_id` sometimes is NaN. Therefore, nullable integer has been used

# %%
extended_schema_dtypes = {
    'id': 'object', 
    'type': 'object', 
    'actor_id': np.int64,
    'actor_login': 'object',
    'actor_gravatar_id': 'object',
    'actor_avatar_url': 'object',
    'actor_url': 'object',
    'repo_id': np.int64,
    'repo_name': 'object', 
    'repo_url': 'object', 
    'payload': 'object', 
    'public': 'bool',
    'created_at': 'datetime64[ns, UTC]', 
    'org_id': pd.Int64Dtype(), 
    'org_login': 'object',
    'org_gravatar_id': 'object',
    'org_avatar_url': 'object',
    'org_url': 'object',
    'other': 'object'}

# %%
df = pd.DataFrame(json_decoded_lines)

df.created_at = pd.to_datetime(df.created_at)

# %%
def expand_dictionary_df_columns(df, dict_cols):
    expanded_data = {}
    for col in dict_cols:
        ind_col_df = df[col].apply(pd.Series, dtype='object')
        ind_col_df = ind_col_df.add_prefix(col + '_') 
        expanded_data.update(ind_col_df)

    expanded_df = pd.DataFrame(expanded_data)

    not_dict_cols_df = df.loc[:, ~df.columns.isin(dict_cols)]
    result_df = pd.concat([not_dict_cols_df, expanded_df], axis=1)

    return result_df

# %%
dict_cols = ['actor', 'repo', 'org']
new_df = expand_dictionary_df_columns(df, dict_cols)

# %%
def _add_missing_columns(df, schema):
    missing_columns = [col for col in schema.keys() if col not in df.columns]
    for col in missing_columns:
        df[col] = pd.Series(dtype=schema[col], name=col)
    return df

# %%
def _drop_columns_not_in_schema(df, schema):
    columns_to_drop = [col for col in df.columns if col not in schema.keys()]
    df = df.drop(columns=columns_to_drop, axis=1)
    return df

# %%
def _adapt_columns_to_schema(df, schema):
    df = _add_missing_columns(df, schema)
    df = _drop_columns_not_in_schema(df, schema)
    return df

# %%
def _apply_schema_types_to_df_columns(df, schema):
    for col, dtype in schema.items():
        if df[col].dtype != dtype:
            try:
                df[col] = df[col].astype(dtype)
            except ValueError:
                print(f'{col} cannot be casted to {dtype}')
    return df

# %%
def convert_df_to_schema(df, schema):
    new_df = df.copy()
    new_df = _adapt_columns_to_schema(new_df, schema)
    new_df = _apply_schema_types_to_df_columns(new_df, schema)
    return new_df

# %%
cleaned_df = convert_df_to_schema(new_df, extended_schema_dtypes)
cleaned_df.to_parquet('test.parquet')

# %%
pd.read_parquet('test.parquet')
# Out:
#                id         type  \
# 0      2489626364  DeleteEvent
# 1      2489626365    PushEvent
# 2      2489626366    PushEvent
# 3      2489626368  DeleteEvent
# 4      2489626369    PushEvent
# ...           ...          ...
# 10302  2489651033    PushEvent
# 10303  2489651038  CreateEvent
# 10304  2489651040  CreateEvent
# 10305  2489651041    PushEvent
# 10306  2489651043    PushEvent
#
#                                                  payload  public  \
# 0      {'action': None, 'before': None, 'comment': No...    True
# 1      {'action': None, 'before': '3ca405ae3d5d899b09...    True
# 2      {'action': None, 'before': 'ebe5f18667b34f7787...    True
# 3      {'action': None, 'before': None, 'comment': No...    True
# 4      {'action': None, 'before': '410e23462261c778e4...    True
# ...                                                  ...     ...
# 10302  {'action': None, 'before': '8f315f0232332f05ab...    True
# 10303  {'action': None, 'before': None, 'comment': No...    True
# 10304  {'action': None, 'before': None, 'comment': No...    True
# 10305  {'action': None, 'before': '1a71a15c719d358d2d...    True
# 10306  {'action': None, 'before': '47251328cda289a0ad...    True
#
#                      created_at  actor_id   actor_login actor_gravatar_id  \
# 0     2015-01-01 14:00:00+00:00   1917297       mooring
# 1     2015-01-01 14:00:00+00:00   1824391     ramirovjr
# 2     2015-01-01 14:00:00+00:00   3101557  mehdisadeghi
# 3     2015-01-01 14:00:00+00:00    844208       annando
# 4     2015-01-01 14:00:00+00:00    963332        srjohn
# ...                         ...       ...           ...               ...
# 10302 2015-01-01 14:59:58+00:00  10358743    weshellnet
# 10303 2015-01-01 14:59:59+00:00   7693186  ashishparkhi
# 10304 2015-01-01 14:59:59+00:00   7732667      lihechao
# 10305 2015-01-01 14:59:59+00:00    667327         sam-d
# 10306 2015-01-01 14:59:59+00:00   4030279         skvoz
#
#                                        actor_url  \
# 0           https://api.github.com/users/mooring
# 1         https://api.github.com/users/ramirovjr
# 2      https://api.github.com/users/mehdisadeghi
# 3           https://api.github.com/users/annando
# 4            https://api.github.com/users/srjohn
# ...                                          ...
# 10302    https://api.github.com/users/weshellnet
# 10303  https://api.github.com/users/ashishparkhi
# 10304      https://api.github.com/users/lihechao
# 10305         https://api.github.com/users/sam-d
# 10306         https://api.github.com/users/skvoz
#
#                                         actor_avatar_url   repo_id  \
# 0       https://avatars.githubusercontent.com/u/1917297?  28670073
# 1       https://avatars.githubusercontent.com/u/1824391?  28444982
# 2       https://avatars.githubusercontent.com/u/3101557?  25783700
# 3        https://avatars.githubusercontent.com/u/844208?   3302872
# 4        https://avatars.githubusercontent.com/u/963332?  28641735
# ...                                                  ...       ...
# 10302  https://avatars.githubusercontent.com/u/10358743?  28670754
# 10303   https://avatars.githubusercontent.com/u/7693186?  27871780
# 10304   https://avatars.githubusercontent.com/u/7732667?  28688589
# 10305    https://avatars.githubusercontent.com/u/667327?  18569518
# 10306   https://avatars.githubusercontent.com/u/4030279?  28687202
#
#                              repo_name  \
# 0                    mooring/smarthost
# 1                     ramirovjr/devops
# 2               mehdisadeghi/mehdix.ir
# 3                    annando/friendica
# 4                   srjohn/johnson.net
# ...                                ...
# 10302  weshellnet/weshellnet.github.io
# 10303                 IDeaSCo/rockstar
# 10304               lihechao/scheduler
# 10305            sam-d/sam-d.github.io
# 10306  skvoz/book_code_complete_theses
#
#                                                 repo_url   org_id org_login  \
# 0         https://api.github.com/repos/mooring/smarthost     <NA>      None
# 1          https://api.github.com/repos/ramirovjr/devops     <NA>      None
# 2      https://api.github.com/repos/mehdisadeghi/mehd...     <NA>      None
# 3         https://api.github.com/repos/annando/friendica     <NA>      None
# 4        https://api.github.com/repos/srjohn/johnson.net     <NA>      None
# ...                                                  ...      ...       ...
# 10302  https://api.github.com/repos/weshellnet/weshel...     <NA>      None
# 10303      https://api.github.com/repos/IDeaSCo/rockstar  8440704   IDeaSCo
# 10304    https://api.github.com/repos/lihechao/scheduler     <NA>      None
# 10305  https://api.github.com/repos/sam-d/sam-d.githu...     <NA>      None
# 10306  https://api.github.com/repos/skvoz/book_code_c...     <NA>      None
#
#       org_gravatar_id                              org_url  \
# 0                None                                 None
# 1                None                                 None
# 2                None                                 None
# 3                None                                 None
# 4                None                                 None
# ...               ...                                  ...
# 10302            None                                 None
# 10303                  https://api.github.com/orgs/IDeaSCo
# 10304            None                                 None
# 10305            None                                 None
# 10306            None                                 None
#
#                                          org_avatar_url other
# 0                                                  None  None
# 1                                                  None  None
# 2                                                  None  None
# 3                                                  None  None
# 4                                                  None  None
# ...                                                 ...   ...
# 10302                                              None  None
# 10303  https://avatars.githubusercontent.com/u/8440704?  None
# 10304                                              None  None
# 10305                                              None  None
# 10306                                              None  None
#
# [10307 rows x 19 columns]
